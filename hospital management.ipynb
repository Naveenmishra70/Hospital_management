# %%
s1=[]
s2=[]
s3=[]
s4=[]
s5=[]
s6=[]
s7=[]
s8=[]
s9=[]
s10=[]
s11=[]
s12=[]
s13=[]
s14=[]
s15=[]
s16=[]
s17=[]
s18=[]
s19=[]
s20=[]


x=int(input( """ Program Options: 
              1) Add new patient 
              2) Print all Patients 
              3) Get Next Patient 
              4) Remove a leaving patient 
              5) End the program 
           
           
             Enter your Choice  (From 1 to 5): """ ))

while(True):
    if x==1:
        d = int(input("""
                         1. Immunologists
                         2. Anesthesiologists
                         3. Cardiologists
                         4. Dermatologists
                         5. Endocrinologists
                         6. Gastroenterologists
                         7. Hematologists
                         8. Internists
                         9. Medical Geneticists
                         10. Nephrologists
                         11. Gynecologist
                         12. Neurologists
                         13. Oncologists
                         14. Osteopaths
                         15. Otolaryngologists
                         16. Plastic surgery
                         17. Radiologists
                         18. Cancer department
                         19. Urologists
                         20. General Surgeons: 

                        Enter Specialization:  """))
        
        n = str(input('Enter the Patient Name '))
        c = int(input(""" 
                          0 - Normal
                          1 - Urgent
                          2 - Critical 
                          
                          Enter Patient Status:"""))
       
        
        
        #g=str(input('Enter the Gender: '))
        #a=int(input('Enter the Age:- '))
        #m=int(input('Enter the mobile number:- '))
        #q=int(input('Enter the Room no.: '))
        
    

        if d==1:
            if len(s1)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s1.append(z)
                    
        
                elif c==1:
                    for i in range(len(s1)):
                        if 'normal' in s1[i]:
                            z=n+' '+'is urgent'
                            s1.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s1.append(z)
                elif c==2:
                    for i in range(len(s1)):
                        if 'urgent' in s1[i]:
                            z=n+' '+'is critical'
                            s1.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s1.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
                
        if d==2:
            if len(s2)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s2.append(z)
        
                elif c==1:
                    for i in range(len(s2)):
                        if 'normal' in s2[i]:
                            z=n+' '+'is urgent'
                            s2.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s2.append(z)
                elif c==2:
                    for i in range(len(s2)):
                        if 'urgent' in s2[i]:
                            z=n+' '+'is critical'
                            s2.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s2.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==3:
            if len(s3)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s3.append(z)
        
                elif c==1:
                    for i in range(len(s3)):
                        if 'normal' in s3[i]:
                            z=n+' '+'is urgent'
                            s3.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s3.append(z)
                elif c==2:
                    for i in range(len(s3)):
                        if 'urgent' in s3[i]:
                            z=n+' '+'is critical'
                            s3.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s3.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==4:
            if len(s4)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s4.append(z)
        
                elif c==1:
                    for i in range(len(s4)):
                        if 'normal' in s4[i]:
                            z=n+' '+'is urgent'
                            s4.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s4.append(z)
                elif c==2:
                    for i in range(len(s4)):
                        if 'urgent' in s4[i]:
                            z=n+' '+'is critical'
                            s4.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s4.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==5:
            if len(s5)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s5.append(z)
        
                elif c==1:
                    for i in range(len(s5)):
                        if 'normal' in s5[i]:
                            z=n+' '+'is urgent'
                            s5.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s5.append(z)
                elif c==2:
                    for i in range(len(s5)):
                        if 'urgent' in s5[i]:
                            z=n+' '+'is critical'
                            s5.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s5.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==6:
            if len(s6)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s6.append(z)
        
                elif c==1:
                    for i in range(len(s6)):
                        if 'normal' in s6[i]:
                            z=n+' '+'is urgent'
                            s6.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s6.append(z)
                elif c==2:
                    for i in range(len(s6)):
                        if 'urgent' in s6[i]:
                            z=n+' '+'is critical'
                            s6.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s6.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==7:
            if len(s7)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s7.append(z)
        
                elif c==1:
                    for i in range(len(s7)):
                        if 'normal' in s7[i]:
                            z=n+' '+'is urgent'
                            s7.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s7.append(z)
                elif c==2:
                    for i in range(len(s7)):
                        if 'urgent' in s7[i]:
                            z=n+' '+'is critical'
                            s7.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s7.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==8:
            if len(s8)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s8.append(z)
        
                elif c==1:
                    for i in range(len(s8)):
                        if 'normal' in s8[i]:
                            z=n+' '+'is urgent'
                            s8.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s8.append(z)
                elif c==2:
                    for i in range(len(s8)):
                        if 'urgent' in s8[i]:
                            z=n+' '+'is critical'
                            s8.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s8.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==9:
            if len(s9)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s9.append(z)
        
                elif c==1:
                    for i in range(len(s9)):
                        if 'normal' in s9[i]:
                            z=n+' '+'is urgent'
                            s9.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s9.append(z)
                elif c==2:
                    for i in range(len(s9)):
                        if 'urgent' in s9[i]:
                            z=n+' '+'is critical'
                            s9.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s9.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==10:
            if len(s10)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s10.append(z)
        
                elif c==1:
                    for i in range(len(s10)):
                        if 'normal' in s10[i]:
                            z=n+' '+'is urgent'
                            s10.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s10.append(z)
                elif c==2:
                    for i in range(len(s10)):
                        if 'urgent' in s10[i]:
                            z=n+' '+'is critical'
                            s10.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s10.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==11:
            if len(s11)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s11.append(z)
        
                elif c==1:
                    for i in range(len(s11)):
                        if 'normal' in s11[i]:
                            z=n+' '+'is urgent'
                            s11.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s11.append(z)
                elif c==2:
                    for i in range(len(s11)):
                        if 'urgent' in s11[i]:
                            z=n+' '+'is critical'
                            s11.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s11.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==12:
            if len(s12)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s12.append(z)
        
                elif c==1:
                    for i in range(len(s12)):
                        if 'normal' in s12[i]:
                            z=n+' '+'is urgent'
                            s12.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s12.append(z)
                elif c==2:
                    for i in range(len(s12)):
                        if 'urgent' in s12[i]:
                            z=n+' '+'is critical'
                            s12.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s12.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        
        if d==13:
            if len(s13)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s13.append(z)
        
                elif c==1:
                    for i in range(len(s13)):
                        if 'normal' in s13[i]:
                            z=n+' '+'is urgent'
                            s13.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s13.append(z)
                elif c==2:
                    for i in range(len(s13)):
                        if 'urgent' in s13[i]:
                            z=n+' '+'is critical'
                            s13.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s13.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        
        if d==14:
            if len(s14)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s14.append(z)
        
                elif c==1:
                    for i in range(len(s14)):
                        if 'normal' in s14[i]:
                            z=n+' '+'is urgent'
                            s14.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s14.append(z)
                elif c==2:
                    for i in range(len(s14)):
                        if 'urgent' in s14[i]:
                            z=n+' '+'is critical'
                            s14.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s14.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==15:
            if len(s15)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s15.append(z)
        
                elif c==1:
                    for i in range(len(s15)):
                        if 'normal' in s15[i]:
                            z=n+' '+'is urgent'
                            s15.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s15.append(z)
                elif c==2:
                    for i in range(len(s15)):
                        if 'urgent' in s15[i]:
                            z=n+' '+'is critical'
                            s15.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s15.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==16:
            if len(s16)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s16.append(z)
        
                elif c==1:
                    for i in range(len(s16)):
                        if 'normal' in s16[i]:
                            z=n+' '+'is urgent'
                            s16.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s16.append(z)
                elif c==2:
                    for i in range(len(s16)):
                        if 'urgent' in s16[i]:
                            z=n+' '+'is critical'
                            s16.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s16.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
       
        if d==17:
            if len(s17)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s17.append(z)
        
                elif c==1:
                    for i in range(len(s17)):
                        if 'normal' in s17[i]:
                            z=n+' '+'is urgent'
                            s17.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s17.append(z)
                elif c==2:
                    for i in range(len(s17)):
                        if 'urgent' in s17[i]:
                            z=n+' '+'is critical'
                            s17.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s17.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==18:
            if len(s18)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s18.append(z)
        
                elif c==1:
                    for i in range(len(s18)):
                        if 'normal' in s18[i]:
                            z=n+' '+'is urgent'
                            s18.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s18.append(z)
                elif c==2:
                    for i in range(len(s18)):
                        if 'urgent' in s18[i]:
                            z=n+' '+'is critical'
                            s18.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s18.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==19:
            if len(s19)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s19.append(z)
        
                elif c==1:
                    for i in range(len(s19)):
                        if 'normal' in s19[i]:
                            z=n+' '+'is urgent'
                            s19.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s19.append(z)
                elif c==2:
                    for i in range(len(s19)):
                        if 'urgent' in s19[i]:
                            z=n+' '+'is critical'
                            s19.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s19.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        if d==20:
            if len(s20)<=10:
                if c==0:
                    z=n+' '+'is normal'
                    s20.append(z)
        
                elif c==1:
                    for i in range(len(s20)):
                        if 'normal' in s20[i]:
                            z=n+' '+'is urgent'
                            s20.insert(i,z)
                            break
                    else:
                        z=n+' '+'is urgent'
                        s20.append(z)
                elif c==2:
                    for i in range(len(s20)):
                        if 'urgent' in s20[i]:
                            z=n+' '+'is critical'
                            s20.insert(i,z)
                            break
                
                    else:
                        z=n+' '+'is critical'
                        s20.insert(0,z)
            else:
                print("Sorry we can't add more patient. Please contact to Nearest Hospital")
        
        x=int(input( """ Program Options: 
              1) Add new patient 
              2) Print all Patients 
              3) Get Next Patient 
              4) Remove a leaving patient 
              5) End the program 
           
           
             Enter your Choice  (From 1 to 5): """ ))
    
    
    if x==2:
        
        def store_data():
            print("Room no. 1  Immunologists: There are ",len(s1)," Patient ")
            for i in s1:
                print('Patient: ',i)
            print()
            
            print("Room no. 2  Anesthesiologists: There are ",len(s2)," Patient ")
            for i in s2:
                print('Patient: ',i)
            print()
            
            print("Room no. 3  Cardiologists: There are ",len(s3)," Patient ")
            for i in s3:
                print('Patient: ',i)
            print()
            
            print("Room no.4 Dermatologists: There are ",len(s4)," Patient ")
            for i in s4:
                print('Patient: ',i)
            print()
            
            print("Room no.5 Endocrinologists: There are ",len(s5)," Patient ")
            for i in s5:
                print('Patient: ',i)
            print()
            
            print("Room no.6  Gastroenterologists: There are ",len(s6)," Patient ")
            for i in s6:
                print('Patient: ',i)
            print()
            
            print("Room no.7 Hematologists: There are ",len(s7)," Patient ")
            for i in s7:
                print('Patient: ',i)
            print()
            
            print("Room no.8 Internists: There are ",len(s8)," Patient ")
            for i in s8:
                print('Patient: ',i)
            print()
            
            print("Room no.9 Medical Geneticists: There are ",len(s9)," Patient ")
            for i in s9:
                print('Patient: ',i)
            print()
            
            print("Room no.10 Nephrologists: There are ",len(s10)," Patient ")
            for i in s10:
                print('Patient: ',i)
            print()
            
            print("Room no.11 Gynecologist: There are ",len(s11)," Patient ")
            for i in s11:
                print('Patient: ',i)
            print()
            
            print("Room no.12 Neurologists: There are ",len(s12)," Patient ")
            for i in s12:
                print('Patient: ',i)
            print()
            
            print("Room no.13  Oncologists: There are ",len(s13)," Patient ")
            for i in s13:
                print('Patient: ',i)
            print()
            
            print("Room no.14 Osteopaths: There are ",len(s14)," Patient ")
            for i in s14:
                print('Patient: ',i)
            print()
            
            print("Room no.15 Otolaryngologists: There are ",len(s15)," Patient ")
            for i in s15:
                print('Patient: ',i)
            print()
            
            print(" Room no.16  Plastic surgery: There are ",len(s16)," Patient ")
            for i in s16:
                print('Patient: ',i)
            print()
            
            print(" Room no.17  Radiologists: There are ",len(s17)," Patient ")
            for i in s17:
                print('Patient: ',i)
            print()
            
            print(" Room no.18 Cancer Department: There are ",len(s18)," Patient ")
            for i in s18:
                print('Patient: ',i)
            print()
            
            print(" Room no.19 Urologists : There are ",len(s19)," Patient ")
            for i in s19:
                print('Patient: ',i)
            print()
            
            print(" Room no.20  General Surgeons: There are ",len(s20)," Patient ")
            for i in s20:
                print('Patient: ',i)
            print()
            
        store_data()
        
        
        x=int(input( """ Program Options: 
              1) Add new patient 
              2) Print all Patients 
              3) Get Next Patient 
              4) Remove a leaving patient 
              5) End the program 
           
           
             Enter your Choice  (From 1 to 5): """ ))
            
            
    elif x==3:
        d=int(input("""
                         1. Immunologists
                         2. Anesthesiologists
                         3. Cardiologists
                         4. Dermatologists
                         5. Endocrinologists
                         6. Gastroenterologists
                         7. Hematologists
                         8. Internists
                         9. Medical Geneticists
                         10. Nephrologists
                         11. Gynecologist
                         12. Neurologists
                         13. Oncologists
                         14. Osteopaths
                         15. Otolaryngologists
                         16. Plastic surgery
                         17. Radiologists
                         18. Cancer department
                         19. Urologists
                         20. General Surgeons: 

                        Enter Specialization:  """))
        if d==1:
            l=len(s1)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s1[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('No patient in Immunologists')
                
        elif d==2:
            l=len(s2)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s2[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in Anesthesiologists')
        elif d==3:
            l=len(s3)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s3[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list3')
        elif d==4:
            l=len(s4)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s4[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list4')
        elif d==5:
            l=len(s5)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s5[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list5')
        elif d==6:
            l=len(s6)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s6[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list6')
        elif d==7:
            l=len(s7)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s7[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list7')
        elif d==8:
            l=len(s8)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s8[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list8')
        elif d==9:
            l=len(s9)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s9[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list9')
        elif d==10:
            l=len(s10)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s10[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list10')
        elif d==11:
            l=len(s11)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s11[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list11')
        elif d==12:
            l=len(s12)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s12[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list12')
        elif d==13:
            l=len(s13)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s13[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list13')
        elif d==14:
            l=len(s14)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s14[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list14')
                
        elif d==15:
            l=len(s15)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s15[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list15')
        elif d==16:
            l=len(s16)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s16[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list16')
        elif d==17:
            l=len(s17)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s17[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list17')
        elif d==18:
            l=len(s18)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s18[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in list18')
        elif d==19:
            l=len(s19)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s19[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in l19')
        elif d==20:
            l=len(s20)
            n=1
            if l>0:
                for i in range(l):
                    print('you are go with the dr.: ',s20[i],'this patient no. going with dr.: ',n)
                    n=n+1
            else:
                print('no patient in l20')
        x=int(input("""enter your choice: 
                enter 1 add new patient
                enter 2 print all patient
                enter 3 get next patient
                enter 4 remove a leaving patient
                enter 5 end the program: """))
                
    elif x==4:
        p=input('enter the name of patient: ')
        d=int(input("""
                         1. Immunologists
                         2. Anesthesiologists
                         3. Cardiologists
                         4. Dermatologists
                         5. Endocrinologists
                         6. Gastroenterologists
                         7. Hematologists
                         8. Internists
                         9. Medical Geneticists
                         10. Nephrologists
                         11. Gynecologist
                         12. Neurologists
                         13. Oncologists
                         14. Osteopaths
                         15. Otolaryngologists
                         16. Plastic surgery
                         17. Radiologists
                         18. Cancer department
                         19. Urologists
                         20. General Surgeons: 

                        Enter Specialization:  """))
        if d==1:
            l=len(s1)
            for i in range(l):
                if p in s1[i]:
                    z=i
            s1.pop(z)
            print('Remaining patient in Immunologists: ',s1)
        elif d==2:
            l=len(s2)
            for i in range(l):
                if p in s2[i]:
                    z=i
            s2.pop(z)
            print('Remaining patient in Anesthesiologists: ',s2)
        elif d==3:
            l=len(s3)
            for i in range(l):
                if p in s3[i]:
                    z=i
            s3.pop(z)
            print('remaining patient in Cardiologists: ',s3)
        elif d==4:
            l=len(s4)
            for i in range(l):
                if p in s4[i]:
                    z=i
            s4.pop(z)
            print('Remaining patient in Dermatologists: ',s4)
        elif d==5:
            l=len(s5)
            for i in range(l):
                if p in s5[i]:
                    z=i
            s5.pop(z)
            print('Remaining patient in Endocrinologists: ',s5)
        elif d==6:
            l=len(s6)
            for i in range(l):
                if p in s6[i]:
                    z=i
            s6.pop(z)
            print('Remaining patient in Gastroenterologists : ',s6)
        elif d==7:
            l=len(s7)
            for i in range(l):
                if p in s7[i]:
                    z=i
            s7.pop(z)
            print('Remaining patient in Hematologists: ',s7)
        elif d==8:
            l=len(s8)
            for i in range(l):
                if p in s8[i]:
                    z=i
            s8.pop(z)
            print('Remaining patient in Internists: ',s8)
        elif d==9:
            l=len(s9)
            for i in range(l):
                if p in s9[i]:
                    z=i
            s9.pop(z)
            print('Remaining patient in Medical Geneticists: ',s9)
        elif d==10:
            l=len(s10)
            for i in range(l):
                if p in s10[i]:
                    z=i
            s10.pop(z)
            print('Remaining patient in Nephrologists: ',s10)
        elif d==11:
            l=len(s11)
            for i in range(l):
                if p in s11[i]:
                    z=i
            s11.pop(z)
            print('Remaining patient in  Gynecologist: ',s11)
        elif d==2:
            l=len(s12)
            for i in range(l):
                if p in s12[i]:
                    z=i
            s12.pop(z)
            print('Remaining patient in Neurologists: ',s12)
        elif d==13:
            l=len(s13)
            for i in range(l):
                if p in s13[i]:
                    z=i
            s13.pop(z)
            print('Remaining patient in Oncologists: ',s13)
        elif d==14:
            l=len(s14)
            for i in range(l):
                if p in s14[i]:
                    z=i
            s14.pop(z)
            print('Remaining patient in Osteopaths: ',s14)
        elif d==15:
            l=len(s15)
            for i in range(l):
                if p in s15[i]:
                    z=i
            s15.pop(z)
            print('Remaining patient in Otolaryngologists: ',s15)
        elif d==16:
            l=len(s16)
            for i in range(l):
                if p in s16[i]:
                    z=i
            s16.pop(z)
            print('Remaining patient in Plastic surgery: ',s16)
        elif d==17:
            l=len(s17)
            for i in range(l):
                if p in s17[i]:
                    z=i
            s17.pop(z)
            print('Remaining patient in Radiologists: ',s17)
        elif d==18:
            l=len(s18)
            for i in range(l):
                if p in s18[i]:
                    z=i
            s18.pop(z)
            print('Remaining patient in Cancer department: ',s18)
        elif d==19:
            l=len(s19)
            for i in range(l):
                if p in s19[i]:
                    z=i
            s19.pop(z)
            print('Remaining patient in Urologists: ',s19)
        elif d==20:
            l=len(s20)
            for i in range(l):
                if p in l20[i]:
                    z=i
            s20.pop(z)
            print('Remaining patient in General Surgeons: ',s20)
            
        x=int(input("""enter your choice: 
                enter 1 add new patient
                enter 2 print all patient
                enter 3 get next patient
                enter 4 remove a leaving patient
                enter 5 end the program: """))
            
    elif x==5:
        
        print("""
                Hope your health is good Thank you for visiting
                              Take care """)
        break
# Out:
#  Program Options:
#               1) Add new patient
#               2) Print all Patients
#               3) Get Next Patient
#               4) Remove a leaving patient
#               5) End the program
#
#
#              Enter your Choice  (From 1 to 5): 5
#
#                 Hope your health is good Thank you for visiting
#                               Take care

# %%
# Out:
# Enter value Immunologists
